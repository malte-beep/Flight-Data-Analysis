# %% [markdown]
# # Flight Data Journey: From Check-In to Landing
#
# Welcome to our flight data analysis journey, where we'll navigate through the data just as a traveler navigates through the airport, from check-in to Landing. Let's embark on this flight journey together.

# %% [markdown]
# # Step 1: Check-In (Initialization)
#
# Just like every journey starts with checking in, our data journey begins with initializing our `FlightDataAnalyzer` class. This step sets up our environment, ensuring all necessary data files are present and accounted for.

# %%
from dotenv import load_dotenv
import os
load_dotenv()  
api_key = os.getenv('OPENAI_API_KEY')
os.chdir("flight_data_analyzer")
from flight_data_analyzer import FlightDataAnalyzer
from IPython.display import display, Markdown
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)


# Initialize the FlightDataAnalyzer
analyzer = FlightDataAnalyzer()
# Out:
# Files extracted to downloads

# %% [markdown]
# # Step 2: Security Check (Data Preparation)
#
# Before we can proceed, we must ensure our data is prepared and secure, just like a thorough security check at the airport. To ensure a smooth security check, we, as seasoned travelers, have already made our class, such as our entire project, PEP 8 compliant beforehand. So let's load our flight data into pandas DataFrames - and remember to remove all liquids above 100ml 😉.
#
# Loading data into pandas DataFrames enables us to efficiently and effectively perform the various data analysis and visualization tasks outlined in the subsequent steps of the notebook.

# %%
# Load the data into dataframes
data_frames = analyzer.data

# %% [markdown]
# # Step 3: Boarding (Data Exploration - Method 1)
#
# With our data prepared, it's time to board. This phase involves diving deeper into our data, exploring the geographical distribution of airports - prepare your boarding passes 🎫.
#
# Building on our boarding step, let's explore the airports of three countries from different continents. This will give us a glimpse into the global distribution of airports. Additionally, we'll attempt to plot airports for a country that does not exist, showcasing the method's error handling capabilities.

# %%
# Plot airports in three countries from different continents
analyzer.plot_country_airports('United States of America').show()  # North America
analyzer.plot_country_airports('Germany').show()  # Europe
analyzer.plot_country_airports('Australia').show()  # Asia

# Attempt to plot airports for a non-existent country
analyzer.plot_country_airports('Adpro Universe').show()  # Non-existent country
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       4 analyzer.plot_country_airports('Australia').show()  # Asia
#       6 # Attempt to plot airports for a non-existent country
# ----> 7 analyzer.plot_country_airports('Adpro Universe').show()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Uni/SoSe 2024/Advanced Programming for Data Science/Group_Project/flight_data_analyzer/flight_data_analyzer.py:162, in FlightDataAnalyzer.plot_country_airports(self, country_name)
#     159 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#     161 if country_name not in world["name"].to_list():
# --> 162     raise ValueError("The provided name does not belong to any country")
#     164 airports_df = self.data['airports']
#     165 country_airports = airports_df[airports_df['Country'] == country_name]
#
# ...

# %% [markdown]
# ### **Comment and Interpretation**
# **United States**<br>
# The distribution of airports across the U.S. reflects not just the country's vast geography but also its economic and social diversity. Airports serve as crucial nodes that connect remote and rural areas with major cities, ensuring economic integration and accessibility. The presence of major international airports along both coasts and near border areas facilitates global connectivity, highlighting the U.S.'s significant role in international travel and commerce.
#
# **Germany**<br>
# Germany's airports are strategically located to serve its population efficiently and act as central nodes in the European and global aviation network. The density of airports in Germany, coupled with the country's advanced transportation infrastructure, ensures excellent connectivity within Europe and beyond. This network supports Germany's economy, particularly in terms of trade, tourism, and international relations.
#
# **Australia**<br>
# Australia's airport distribution highlights the country's unique challenge of connecting distant urban centers across a vast continent while also serving remote communities. The concentration of airports along the coast where the majority of the population lives supports domestic connectivity and international access. Meanwhile, airports in the interior play a critical role in servicing remote communities, underlining the importance of aviation in maintaining national cohesion and access to services.
#
# **Summary** <br>
# By examining the distribution of airports within these three countries, we can infer the role of geography, population distribution, and economic factors in shaping their aviation infrastructure. The United States demonstrates how a country can manage both extensive domestic and international connectivity. Germany shows the impact of strategic location and infrastructure in enhancing regional and international linkages. Australia reveals how aviation is vital in overcoming geographical challenges, ensuring connectivity across vast distances and between densely and sparsely populated areas. This analysis underscores the significance of airports in facilitating mobility, economic development, and integration in diverse geographic and socio-economic contexts.
#
# **Additional Remarks** <br>
# In our analysis of the data plots for Germany and Australia, we encountered a curious phenomenon: outliers that appeared to represent airports located outside the boundaries of these countries. Upon further inspection of the dataset, it was confirmed that these anomalies were due to inaccuracies in the listed latitude and longitude coordinates for some airports, suggesting they exist where they, in fact, do not.
#
# To address this issue, there are a couple of straightforward solutions. One could manually go through the dataset and remove the entries for these non-existent airports. Alternatively, a more automated approach would involve setting constraints on the latitude and longitude values, limiting them to the actual geographical boundaries of each country. This method ensures that only airports genuinely located within Germany and Australia are considered in our analysis, enhancing the accuracy of our findings.

# %% [markdown]
# # Step 4: Take-Off (First Analysis - Method 2)
#
# Delving deeper into our take-off phase, we'll perform a distance analysis of the flights. This analysis will help us understand the distribution of flight distances, highlighting the prevalence of short-distance flights. Please fasten your seat belts and switch your electronic devices to flight-mod.

# %%
# Perform distance analysis and plot the results
plt = analyzer.distance_analysis()
plt.show()

# %% [markdown]
# ### **Comment and Interpretation:**
#
# The histogram displays the distribution of flight distances, revealing a significant concentration of routes within the 0 to 2000 kilometers range. This suggests that short-haul flights dominate the dataset, indicating a robust network of regional air travel. The steep decline in the number of routes as distance increases confirms that long-distance flights are less frequent.
#
# The abundance of shorter routes may reflect several factors, including the prevalence of domestic flights within countries, the importance of connecting close international destinations, and potentially the preference for air travel for medium-distance journeys due to convenience and time savings compared to other modes of transportation.
#
# Additionally, the relatively small number of routes beyond 2000km corrsespond to long-haul international flights, which are naturally less frequent due to the limited number of destinations within that range and the higher operational costs associated with these flights. The data presented in this histogram is incredibly valuable for airlines and airport authorities as it highlights the importance of regional connectivity and the potential market for short to medium-haul flights. It also underscores the need for infrastructure and policies that support the high volume of shorter routes, which are crucial for the overall accessibility and efficiency of the aviation network.

# %% [markdown]
# # Step 5: In-Flight Entertainment (Further Insights)
#
# During our flight, let's enjoy some in-flight entertainment by uncovering further insights and analyses from our data - feel free to take a look at our board menu.

# %% [markdown]
# ## Step 5.1: Diverse Flight Patterns from Airports (Method 3)
#
# Exploring flight patterns from Lisbon Airport (LIS), we'll compare the difference between all flights and only national flights. This comparison will illustrate the airport's role in both international and domestic travel.

# %%
# Plot all flights departing from Airports
analyzer.plot_flights_by_airport('FRA', internal=False).show()  # All flights Frankfurt Airport
analyzer.plot_flights_by_airport('ATL', internal=False).show()  # All flights Atlanta Airport

# Plot only national flights departing from Airports
analyzer.plot_flights_by_airport('FRA', internal=True).show()  # Domestic flights Frankfurt Airport
analyzer.plot_flights_by_airport('ATL', internal=True).show()  # Domestic flights Atlanta Airport

# %% [markdown]
# ### **Comment and Interpretation**
#
# Building on our previous discussion on the air travel dynamics within the United States and Germany, let's integrate those insights into the comparison between Hartsfield-Jackson Atlanta International Airport (ATL) and Frankfurt Airport (FRA), as seen through their flight patterns.
#
# **Comment and Interpretation**<br>
# The analysis of flight patterns from ATL and FRA, considering both all flights and exclusively domestic flights, reveals distinct characteristics of each airport that align with the broader air travel trends in the United States and Germany.
#
# **ATL (Hartsfield-Jackson Atlanta International Airport):** The plots for ATL vividly illustrate its dominance in the domestic air travel sector in the United States. The visualization of all flights from ATL showcases a dense network of domestic routes spanning the entire country, underscoring the airport's pivotal role in connecting various US cities. This domestic intensity significantly overshadows the international connections, although ATL also serves as a notable gateway for flights to international destinations. The comparison between all flights and domestic-only flights at ATL highlights the substantial volume and coverage of its domestic operations, which is a testament to the extensive air travel infrastructure within the United States that facilitates such a vast web of internal connections.
#
# **FRA (Frankfurt Airport):** For FRA, the flight patterns underscore its strategic importance as a global transit hub, especially for international flights. The visualization from FRA shows a rich tapestry of international connections that span continents, reflecting Germany's central role in global air travel and its strategic geographic location in Europe. The domestic flight plot, while less dense than the international one, still reveals a network of routes within Germany, although these are considerably overshadowed by the international routes. This distribution aligns with Germany's efficient ground transportation system and the presence of multiple major airports, which together reduce the reliance on domestic air travel.
#
# **Conclusion**<br>
# The flight patterns from ATL and FRA provide a clear depiction of each airport's role within their respective air travel ecosystems. ATL's flight patterns reinforce its status as a cornerstone of the US domestic air travel network, with a significant but smaller proportion of international flights. In contrast, FRA's patterns highlight its critical function as an international hub, with a large amount of global connections that exceed its domestic flights. This analysis not only reflects the operational focus of each airport but also mirrors the broader air travel preferences and infrastructure in the United States and Germany. Through these insights, we gain a deeper understanding of the strategic significance and the contrasting roles that ATL and FRA play in facilitating both domestic and international air travel.

# %% [markdown]
# ## Step 5.2: Airplane Models and Routes (Method 4)
#
# In this step, we delve into the characteristics of global and regional aviation trends by analyzing the usage frequency of various aircraft models. Through this analysis, we aim to uncover insights into the operational preferences that shape the global and localized landscapes of air travel.

# %%
# Show whole dataset
print("Whole World:")
analyzer.most_airplane_model().show()
# Show only Germany
print("Germany:")
analyzer.most_airplane_model("Germany").show()
# Show only United States
print("United States:")
analyzer.most_airplane_model("United States of America").show()
# Out:
# Whole World:
# Germany:
# United States:

# %% [markdown]
# ### **Comment and Interpretation**
#
# **All Dataset (Global Overview):** <br>
# The analysis reveals that the Airbus A320 is the predominant aircraft model used worldwide, followed by the Boeing 737-800, Airbus A319, Airbus A321, and then the model coded as 73H. This pattern illustrates the global aviation sector's preference for narrow-body, single-aisle aircraft. These models are favored due to their balance of efficiency, range, and passenger capacity, making them well-suited for a variety of routes from short to medium-haul. Notably, the A320 and 737-800 are preferred for their operational efficiency and the flexibility they provide airlines in serving a diverse array of flight paths.
#
# **Germany (Specific Country Focus):** <br>
# For Germany, the data illustrates a slight variance in preference with the Airbus A319 and A320 leading in utilization, followed by the 738, which is likely a shorthand for the Boeing 737-800. Additionally, the Airbus A321 and the model coded as 73H make a strong showing, suggesting a similar trend in aircraft selection as observed globally. The inclusion of regional jet models like the CRJ points to the critical role of regional flights in Germany, likely serving its robust network of intra-European routes as well as some domestic flights. The selection of aircraft within Germany reflects its strategic importance as a hub in European air travel, facilitating a mix of short to medium-haul flights.
#
# **USA (Individual Country Focus):** <br>
# In the United States, the analysis of the most used airplane models reveals a notable preference for the Airbus A320, leading the fleet utilization across various routes. This is closely followed by the Boeing 737 models, with the 737-300 and 737-800 demonstrating their prominence in the US market. Additionally, the Canadair Regional Jet ('CRJ') marks its importance for regional connectivity, a testament to the intricate network of domestic flights that stitch the country together. The data also shows the use of other models such as the Boeing 737-300, 737-300, and the McDonnell Douglas MD-80, suggesting that airlines favor a mix of aircraft to cater to different operational requirements from short-haul to transcontinental flights. The selection of these models underscores the importance of versatility and operational efficiency in the US aviation sector, where a diverse range of aircraft is employed to serve the vast and varied landscape of American air travel.
#
# **Conclusion:**
# The overall data presents a clear indication that the Airbus A320 and Boeing 737 families are the backbone of the airline industry in the United States, mirroring global preferences for narrow-body, single-aisle aircraft. Their operational efficiency and ability to adapt to different route profiles make them the aircraft of choice for airlines. The inclusion of the CRJ series and other Boeing models points to a strategic approach in fleet diversification, allowing for comprehensive coverage of both short and extensive routes. This trend aligns with the global and German patterns, highlighting the significance of these aircraft in maintaining a robust and responsive air travel infrastructure.

# %% [markdown]
# ## Step 5.3: Additional Aircraft and Airport Info (LLM Methods - Day 2)
#
# After analysing diverse flight patterns from airports in step 5.1 and most common aircraft models and routes in step 5.2, we want to provide some additional information about the discussed airports and aircrafts in this step. To show these information we use a LLM API to generate the tables.
#
# Let´s start with displaying more information about the two most common aircraft models - the Airbus A320 and Boeing 737-800.

# %%
# Show information about aircraft models (generated by a LLM)
display(Markdown(analyzer.aircraft_info("Airbus A320")))
display(Markdown(analyzer.aircraft_info("Boeing 738")))
# Out:
# | Aircraft        | Airbus A320                                              |
# |-----------------|------------------------------------------------------------|
# | Manufacturer    | Airbus                                                     |
# | First flight    | 1987                                                      |
# | Capacity        | Approximately 150 passengers                              |
# | Range           | 3,300 nautical miles                                       |
# | Common use      | Short to medium haul                                       |
# | Notable features| Fuel-efficient engines, advanced cockpit technology       |
# | Variants        | A320neo, A320ceo, A319, A321                              |
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Show information about aircraft models (generated by a LLM)
# ...

# %% [markdown]
# Ups, it seems like we have run into some turbulence - we misspelled the second aircraft name. Let´s print a list of all aircraft models to find the correct name.

# %%
analyzer.aircrafts()
# Out:
# ['Aerospatiale (Nord) 262', 'Aerospatiale (Sud Aviation) Se.210 Caravelle', 'Aerospatiale SN.601 Corvette', 'Aerospatiale/Alenia ATR 42-300', 'Aerospatiale/Alenia ATR 42-500', 'Aerospatiale/Alenia ATR 42-600', 'Aerospatiale/Alenia ATR 72', 'Airbus A300', 'Airbus A300-600', 'Airbus A300-600ST Super Transporter / Beluga', 'Airbus A310', 'Airbus A318', 'Airbus A319', 'Airbus A319neo', 'Airbus A320', 'Airbus A320neo', 'Airbus A321', 'Airbus A321neo', 'Airbus A330', 'Airbus A330-200', 'Airbus A330-300', 'Airbus A330-700 Beluga XL', 'Airbus A330-800neo', 'Airbus A330-900neo', 'Airbus A340', 'Airbus A340-200', 'Airbus A340-300', 'Airbus A340-500', 'Airbus A340-600', 'Airbus A350', 'Airbus A350-1000', 'Airbus A350-900', 'Airbus A380', 'Airbus A380-800', 'Antonov AN-12', 'Antonov AN-124 Ruslan', 'Antonov AN-140', 'Antonov An-148', 'Antonov An-158', 'Antonov An-225 Mriya', 'Antonov AN-24', 'Antonov AN-26', 'Antonov AN-28', 'Antonov AN-30', 'Antonov AN-32', 'Antonov AN-72', 'Avro RJ100', 'Avro 
# ...

# %% [markdown]
# Now that we see the list, lets print the information for the correct aircraft model.

# %%
display(Markdown(analyzer.aircraft_info("Boeing 737-800")))
# Out:
# | Aircraft        | Boeing 737-800                                             |
# |-----------------|------------------------------------------------------------|
# | Manufacturer    | Boeing                                                     |
# | First flight    | 1997                                                       |
# | Capacity        | Approximately 160-189 passengers                           |
# | Range           | 3,115 nautical miles                                       |
# | Common use      | Short to medium-haul                                       |
# | Notable features| Fuel-efficient engines, blended winglets                    |
# | Variants        | Boeing Business Jet (BBJ) 2, Boeing Converted Freighter (BCF) |

# %% [markdown]
# Interesting insights! Let´s also display some additional information about the two airports we have analyzed before. We will start by printing the list of all available airports.

# %%
# Print list of all airports
analyzer.airports()

# Print information about Frankfurt airport
display(Markdown(analyzer.airport_info("FRA")))

# Print information about Atlanta airport
display(Markdown(analyzer.airport_info("ATL")))
# Out:
# ['Goroka', 'Madang', 'Mount Hagen', 'Nadzab', 'Port Moresby', 'Wewak', 'Narssarssuaq', 'Godthaab', 'Sondrestrom', 'Thule', 'Akureyri', 'Egilsstadir', 'Hofn', 'Husavik', 'Isafjordur', 'Keflavik', 'Patreksfjordur', 'Reykjavik', 'Siglufjordur', 'Vestmannaeyjar', 'Sault Sainte Marie', 'Winnipeg', 'Halifax', 'St. Anthony', 'Tofino', 'Pelly Bay', 'Baie Comeau', 'Bagotville', 'Baker Lake', 'Campbell River', 'Brandon', 'Cambridge Bay', 'Nanaimo', 'Castlegar', 'Chatham', 'Charlo', 'Coppermine', 'Coronation', 'Chilliwack', 'Clyde River', 'Coral Harbour', 'Dawson', 'Burwash', 'Princeton', 'Deer Lake', 'Dease Lake', 'Dauphin', 'Dawson Creek', 'Edmonton', 'Eskimo Point', 'Estevan', 'Edson', 'Eureka', 'Inuvik', 'Iqaluit', 'Fredericton', 'Forestville', 'Flin Flon', 'Fort Resolution', 'Fort Simpson', 'Kingston', 'La Grande Riviere', 'Gaspe', 'Geraldton', 'Iles De La Madeleine', 'Hudson Bay', 'Dryden', 'Holman Island', 'Gjoa Haven', 'Hamilton', 'Montreal', 'Hay River', 'Halifax', 'Atikokan', 'Pond In
# ...

# %% [markdown]
# # Step 6: Podcast Time (Method 5)
#
# After hours of reading the board menu and watching the new released Dune 2, you want to close your eyes for a bit and listen to a podcast 🎧. You have downloaded an episode about a mini-casestudy - Decarbonisation. This casestudy explores how railservices, as an alternative to short-haul flights, can reduce emissions in Australia.
#
# The information in the podcast are based on the following references:<br>
# CO2/ passenger km Rail in Australia: https://ara.net.au/wp-content/uploads/REPORT-ValueofRail2020-1.pdf<br>
# CO2/ passenger km short haul flight: https://ourworldindata.org/travel-carbon-footprint<br>

# %%
# Plot all flights departing from Australia
analyzer.plot_flights_by_country('Australia', internal=False, cutoff_distance=1000).show()  # All flights Australia

# Plot only domestic flights departing from Australia
analyzer.plot_flights_by_country('Australia', internal=True, cutoff_distance=1000).show()  # Only domestic flights Australia

# %% [markdown]
# ### **Comment and Interpretation**
#
# **Global Emissions Insights:** <br>
# The first plot displays all flights departing from Australia, both international and domestic, providing a global perspective on the country's aviation footprint. In this broader context, the reduction of emissions by replacing short-haul flights with rail services is a significant step. With a reported reduction of **10,601.35 kg CO2-eq**, this move underscores the substantial impact that even international transit hubs like Australia can have on global carbon emissions by focusing on sustainable short-haul travel solutions within their boundaries.
#
# **Domestic Emissions Insights:** <br>
# The second plot, concentrating solely on domestic flights, reveals the dense network of short-haul flights that knit together the vast Australian landscape. The potential emissions reduction in this context stands at **10,364.66 kg CO2-eq**, marginally less than the global reduction potential. This indicates that while Australia's domestic short-haul flights are substantial, the additional international routes contribute a non-negligible amount to the potential emissions savings. It suggests that focusing on domestic travel alone might not capture the full scope of environmental benefits achievable.
#
# **CO2 Emissions Reduction Differences:** <br>
# The slight difference in CO2 emissions reduction between the two plots can be attributed to the few international short-haul flights that originate from Australia. The majority of international flights however, are above the 1000km cutoff distance. The large size of international long-haul flights emphasizes the need for a dual approach in policy-making that encourages emissions reduction in both domestic and international spheres.
#
# **Australia-Specific Considerations:** <br>
# The intricate web of short-haul flights within Australia, evident in the second plot, indicates that a significant number of travelers could potentially shift to rail transport for their domestic journeys. Australia's vast outback and urbanized coastal cities create a unique challenge for rail infrastructure to become a competitive alternative to air travel. However, the relatively shorter distances between major cities like Sydney, Melbourne, Brisbane, and others suggest that enhancing rail services could effectively replace a substantial number of domestic flights, thereby reducing the overall carbon footprint.
#
# **Conclusion** <br>
# Analyzing both international and domestic departure routes paints a comprehensive picture of the aviation sector's impact on Australia's environmental goals. It is apparent that while the shift to rail services for short-haul flights shows great promise for emissions reduction domestically, Australia's role as an international connector should not be overlooked. The cumulative effect of both domestic and international flight replacement could result in a marked improvement in the country's carbon emissions profile. These insights compel a more nuanced approach to Australia's travel infrastructure, promoting sustainable alternatives that cater to both internal mobility and international connectivity.

# %% [markdown]
# # Step 7: Landing (Conclusion)
#
# As we prepare for landing, let's summarize our journey, highlighting the key insights and findings from our analysis - please make sure your seat backs and tray tables are in their full upright position.
#
# Through the implementation of five distinct methods, each designed to explore specific facets of air travel, we have uncovered patterns and trends that reflect the operational, geographical, and strategic nuances of the aviation industry. Here's a concise summary of our journey and the key findings:

# %% [markdown]
# **Method 1: Airports Across Continents**<br>
# Our journey began with an exploration of airports across three distinct countries from three different continents, providing a geographical spread that highlighted the diversity of aviation infrastructure globally. This method set the stage for our analysis by emphasizing the global reach of our investigation and the varied contexts within which airports operate.
#
# **Method 2: Exploration of Flight Durations**<br>
# We then shifted our focus to flight durations, analyzing the spectrum from short-haul to long-haul flights. This exploration unearthed insights into the temporal dimensions of air travel, revealing how flight durations vary widely, reflecting the vast distances covered by the aviation network and the efficiency of different aircraft models in bridging these gaps
#
# **Method 3: Flight Patterns from Specific Airports**<br>
# Focusing on individual airports, we compared flight patterns from Hartsfield-Jackson Atlanta International Airport (ATL) and Frankfurt Airport (FRA), illustrating the contrast between ATL's domestic dominance and FRA's global outreach. This comparison underscored the impact of geographic location and national infrastructure on the operational focus of airports.
#
# **Method 4: Aircraft Model Utilization**<br>
# We analyzed the most used airplane models, revealing preferences that span from regional workhorses to long-range jets. This method highlighted the Airbus A320 and Boeing 737 families' prominence, reflecting their adaptability to various market demands and operational strategies.
#
# **LLM Methods: Aircraft and Airport Information**<br>
# After analyzing flight patterns from airports and aircraft model utilization, we showed additional information about the discussed airports, Frankfurt and Atlanta, as well as the most common aircraft models, Airbus 320 and Boeing 737-800. To show these information, we used an LLM API to generate the tables.
#
# **Method 5: Decarbonization through Short-haul Analysis**<br>
# Our inquiry extended into the environmental impact of aviation with a study of Australia's flight patterns, discerning short-haul and long-haul routes. We quantified the potential for emissions reduction by considering rail replacements for short-haul flights, underscoring the significant ecological benefits within the country's unique travel network.
#
# **Conclusion**<br>
# In summary, our comprehensive analysis underscores the complexity and diversity of global aviation, highlighting the critical role of geographic, economic, and strategic factors in shaping the world's air travel patterns. This journey through data not only offers insights into current trends but also lays the groundwork for future explorations into the ever-evolving skies of global aviation.
#
# Thank you for choosing to fly with us today - we hope you enjoyed the insightful journey
